# %%
import pandas as pd
import numpy as np

# %%
df1 = pd.read_csv('/Users/ccoyle/OneDrive - Manhattan Associates/Grad School/Fall 2020/DVA/Project/lyrics/df_withlyrics_0-50.csv')
df2 = pd.read_csv('/Users/ccoyle/OneDrive - Manhattan Associates/Grad School/Fall 2020/DVA/Project/lyrics/df_withlyrics_51-100.csv')
df3 = pd.read_csv('/Users/ccoyle/OneDrive - Manhattan Associates/Grad School/Fall 2020/DVA/Project/lyrics/df_withlyrics_101-150.csv')
df4 = pd.read_csv('/Users/ccoyle/OneDrive - Manhattan Associates/Grad School/Fall 2020/DVA/Project/lyrics/df_withlyrics_151-200.csv')
df5 = pd.read_csv('/Users/ccoyle/OneDrive - Manhattan Associates/Grad School/Fall 2020/DVA/Project/lyrics/df_withlyrics_201-250.csv')
df6 = pd.read_csv('/Users/ccoyle/OneDrive - Manhattan Associates/Grad School/Fall 2020/DVA/Project/lyrics/df_withlyrics_251-300.csv')
df7 = pd.read_csv('/Users/ccoyle/OneDrive - Manhattan Associates/Grad School/Fall 2020/DVA/Project/lyrics/df_withlyrics_301-350.csv')
df8 = pd.read_csv('/Users/ccoyle/OneDrive - Manhattan Associates/Grad School/Fall 2020/DVA/Project/lyrics/df_withlyrics_351-400.csv')

# %%
frames = [df1, df2, df3, df4, df5, df6, df7, df8]

final_df = pd.concat(frames).drop(['Unnamed: 0'], axis=1)

# %%
final_df
# Out:
#                      track_id  \
# 0      4YYCyU5iK3l71ksslONDAd
# 1      16yp5qRfetwD96yOdTdF61
# 2      1mtAjLKBl0RLs5u2Llb6mF
# 3      4SaMDXfjGHmk3uV59HRFXR
# 4      3hO8Z3VNhqYITfuRWWgVvM
# ...                       ...
# 41543  2JY50y1VWfY9mHkhlqZB72
# 41544  7hhxYmwbm1fsS5gZQyFEkU
# 41545  0MBM0Aw6RBuG2NZDvRIXPV
# 41546  6v1fLmGLQJFfOCa2vSI0LR
# 41547  08AvYph03KYqs2JHK6WaLg
#
#                                                   artist  \
# 0                                 ''Sugar Boy'' Crawford
# 1             'Anything Goes' New Broadway Cast Ensemble
# 2         'Brigadoon' 2017 New York City Center Ensemble
# 3         'Brigadoon' 2017 New York City Center Ensemble
# 4      'Brigadoon' 2017 New York City Center Male Ens...
# ...                                                  ...
# 41543                                          猫 シ Corp.
# 41544                                               碧海祐人
# 41545                                               穴山 昴
# ...

# %%
final_df.isnull().sum()
# Out:
# track_id                 0
# artist                   3
# song_name                0
# popularity               0
# album                    0
# isrc                     0
# danceability             0
# energy                   0
# key                      0
# loudness                 0
# mode                     0
# speechiness              0
# acousticness             0
# instrumentalness         0
# liveness                 0
# valence                  0
# tempo                    0
# type                     0
# id                       0
# uri                      0
# track_href               0
# analysis_url             0
# duration_ms              0
# time_signature           0
# lyrics              102542
# dtype: int64

# %%
final_df.to_csv('final_df_withlyrics.csv')
